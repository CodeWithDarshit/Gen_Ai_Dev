# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# %%
propts = [
  {"role":"user", "content":"hello , i am darshit"},
  {"role": "ai", "content": "hello , darshit devmurarinr how can learn"},
  {"role": "user", "content":"what is my name "}
]

res = llm.invoke(propts)
res.content
# Out:
# 'Your name is Darshit.'

# %% [markdown]
# Manage Histroy

# %%
history = [

] 

while True:
  query = input("user: ")
  if query.lower() in ["exit", "quite"]:
    print("good buy")
    break
  history.append({"role": "user", "content": query})
  print("user: ", query)
  res = llm.invoke(history)
  history.append({"role": "ai", "content": res.content})

  print("AI: ", res.content, "\n")
# Out:
# user:
# c:\Gen_Ai_Dev\lect2\env\Lib\site-packages\langchain_google_genai\chat_models.py:3005: UserWarning: HumanMessage with empty content was removed to prevent API error
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 12
#       8     print("good buy")
#       9     break
#      10   history.append({"role": "user", "content": query})
#      11   print("user: ", query)
# ---> 12   res = llm.invoke(history)
#      13   history.append({"role": "ai", "content": res.content})
#      14
#      15   print("AI: ", res.content, "\n")
#
# File c:\Gen_Ai_Dev\lect2\env\Lib\site-packages\langchain_google_genai\chat_models.py:2672, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    2669         msg = "Tools are already defined.code_execution tool can't be defined"
#    2670         raise ValueError(msg)
# -> 2672 return super().invoke(input, config, stop=stop, **kwargs)
#
# File c:\Gen_Ai_Dev\lect2\env\Lib\site-packages\langchain_core\language_models\chat_models.py:474, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     460 @override
#     461 def invoke(
#     462     self,
#    (...)    467     **kwargs: Any,
#     468 ) -> AIMessage:
#     469     config = ensure_config(config)
#     470     return cast(
#     471         "AIMessage",
#     472         cast(
#     473             "ChatGeneration",
# --> 474             self.generate_prompt(
#     475                 [self._convert_input(input)],
#     476                 stop=stop,
#     477                 callbacks=config.get("callbacks"),
#     478                 tags=config.get("tags"),
#     479                 metadata=config.get("metadata"),
#     480                 run_name=config.get("run_name"),
#     481                 run_id=config.pop("run_id", None),
#     482                 **kwargs,
#     483             ).generations[0][0],
#     484         ).message,
#     485     )
#
# File c:\Gen_Ai_Dev\lect2\env\Lib\site-packages\langchain_core\language_models\chat_models.py:1823, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1814 @override
#    1815 def generate_prompt(
#    1816     self,
#    (...)   1820     **kwargs: Any,
#    1821 ) -> LLMResult:
#    1822     prompt_messages = [p.to_messages() for p in prompts]
# -> 1823     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Gen_Ai_Dev\lect2\env\Lib\site-packages\langchain_core\language_models\chat_models.py:1630, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1627 for i, m in enumerate(input_messages):
#    1628     try:
#    1629         results.append(
# -> 1630             self._generate_with_cache(
#    1631                 m,
#    1632                 stop=stop,
#    1633                 run_manager=run_managers[i] if run_managers else None,
#    1634                 **kwargs,
#    1635             )
#    1636         )
#    1637     except BaseException as e:
#    1638         if run_managers:
#
# File c:\Gen_Ai_Dev\lect2\env\Lib\site-packages\langchain_core\language_models\chat_models.py:1970, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1968     result = generate_from_stream(iter(chunks))
#    1969 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1970     result = self._generate(
#    1971         messages, stop=stop, run_manager=run_manager, **kwargs
#    1972     )
#    1973 else:
#    1974     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Gen_Ai_Dev\lect2\env\Lib\site-packages\langchain_google_genai\chat_models.py:3194, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3181 request = self._prepare_request(
#    3182     messages,
#    3183     stop=stop,
#    (...)   3191     **kwargs,
#    3192 )
#    3193 try:
# -> 3194     response: GenerateContentResponse = self.client.models.generate_content(
#    3195         **request,
#    3196     )
#    3197 except ClientError as e:
#    3198     _handle_client_error(e, request)
#
# File c:\Gen_Ai_Dev\lect2\env\Lib\site-packages\google\genai\models.py:6480, in Models.generate_content(self, model, contents, config)
#    6478 while remaining_remote_calls_afc > 0:
#    6479   i += 1
# -> 6480   response = self._generate_content(
#    6481       model=model, contents=contents, config=parsed_config
#    6482   )
#    6484   function_map = _extra_utils.get_function_map(parsed_config)
#    6485   if not function_map:
#
# File c:\Gen_Ai_Dev\lect2\env\Lib\site-packages\google\genai\models.py:4892, in Models._generate_content(self, model, contents, config)
#    4890     path = '{model}:generateContent'
#    4891 else:
# -> 4892   request_dict = _GenerateContentParameters_to_mldev(
#    4893       self._api_client, parameter_model, None, parameter_model
#    4894   )
#    4895   request_url_dict = request_dict.get('_url')
#    4896   if request_url_dict:
#
# File c:\Gen_Ai_Dev\lect2\env\Lib\site-packages\google\genai\models.py:1636, in _GenerateContentParameters_to_mldev(api_client, from_object, parent_object, root_object)
#    1624   setv(
#    1625       to_object,
#    1626       ['_url', 'model'],
#    1627       t.t_model(api_client, getv(from_object, ['model'])),
#    1628   )
#    1630 if getv(from_object, ['contents']) is not None:
#    1631   setv(
#    1632       to_object,
#    1633       ['contents'],
#    1634       [
#    1635           _Content_to_mldev(item, to_object, root_object)
# -> 1636           for item in t.t_contents(getv(from_object, ['contents']))
#    1637       ],
#    1638   )
#    1640 if getv(from_object, ['config']) is not None:
#    1641   setv(
#    1642       to_object,
#    1643       ['generationConfig'],
#    (...)   1646       ),
#    1647   )
#
# File c:\Gen_Ai_Dev\lect2\env\Lib\site-packages\google\genai\_transformers.py:482, in t_contents(contents)
#     476 def t_contents(
#     477     contents: Optional[
#     478         Union[types.ContentListUnion, types.ContentListUnionDict, types.Content]
#     479     ],
#     480 ) -> list[types.Content]:
#     481   if contents is None or (isinstance(contents, list) and not contents):
# --> 482     raise ValueError('contents are required.')
#     483   if not isinstance(contents, list):
#     484     return [t_content(contents)]
#
# ValueError: contents are required.
