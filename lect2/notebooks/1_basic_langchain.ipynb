# %% [markdown]
# Load ENv variable

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# Running cells with '.venv (3.14.5.final.0) (Python 3.14.5)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Gen_Ai_Dev/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
import os

# %%
from langchain_google_genai import ChatGoogleGenerativeAI


# llm object
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# %%
res = llm.invoke("next 5 year ai is good or not")
print(res.content)
# Out:
# Predicting the exact impact of AI over the next five years is challenging, as it's a rapidly evolving field. However, we can anticipate both significant benefits and potential drawbacks.
#
# **Here's a breakdown of why AI is likely to be "good" and "not so good" in the next five years:**
#
# **The "Good" Aspects of AI in the Next 5 Years:**
#
# *   **Enhanced Productivity and Efficiency:**
#     *   **Automation:** AI will continue to automate repetitive and mundane tasks across industries, freeing up humans for more complex and creative work. This can lead to increased output and reduced operational costs.
#     *   **Improved Decision-Making:** AI can analyze vast datasets to identify patterns and insights that humans might miss, leading to more informed and effective decisions in business, healthcare, finance, and more.
# ...
