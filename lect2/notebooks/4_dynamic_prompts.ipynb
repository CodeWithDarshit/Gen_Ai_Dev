# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# %%
prompts = [
  {"role":"system", "content":"you are a java developer"},
  {"role": "user", "content":"explain two sum of array in interview qeustion and answer"},
]

res = llm.invoke(prompts)
print(res.content)
# Out:
# Let's dive into the "Two Sum" problem, a classic interview question for Java developers.
#
# ## The "Two Sum" Problem: Interview Question
#
# **Question:**
#
# Given an array of integers `nums` and an integer `target`, return the indices of the two numbers such that they add up to `target`.
#
# You may assume that each input would have exactly one solution, and you may not use the same element twice.
#
# **Example 1:**
#
# ```
# Input: nums = [2, 7, 11, 15], target = 9
# Output: [0, 1]
# Explanation: Because nums[0] + nums[1] == 9, we return [0, 1].
# ```
#
# **Example 2:**
#
# ```
# Input: nums = [3, 2, 4], target = 6
# Output: [1, 2]
# ```
#
# **Example 3:**
#
# ```
# Input: nums = [3, 3], target = 6
# Output: [0, 1]
# ```
#
# ---
#
# ## Explanation and Approaches
#
# This problem is about finding a pair of numbers in an array that sum up to a specific target value. The key is to efficiently search for the "complement" of each number.
#
# ...

# %%
# prompts = [
#   {"role":"system", "content":"you are a java developer in hindi"},
#   {"role": "user", "content":"explain two sum of array in interview qeustion and answer code and explain logic and much more "},
# ]

# res = llm.invoke(prompts)
# print(res.content)

# %% [markdown]
# prompts template - dynamic prompts

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
out  = StrOutputParser()

# %%
# my self chain mode

# %%
def transform_case(result:str):
  return result.upper()

# %%
prompts = ChatPromptTemplate.from_messages([
  {"role":"system", "content":"you are a java developer {language}"},
  {"role": "user", "content":"{query}"},
])

# %%
# final_prompts = prompts.format_messages(language = "english", query = "i love python and java")

# res = llm.invoke(final_prompts)
# print(res.content)

# %%
##chains - runnable

# %%
# res = llm.invoke(prompts.invoke({"language": "english", "query":"ilove you"}).messages
# )

# res.content

# %%
##chains

# %%
chains = prompts | llm | out | transform_case

# %%
# chains

# %%
res = chains.invoke({"language": "english", "query":"ilove you?"})
print(res)
# Out:
# I AM A LARGE LANGUAGE MODEL, TRAINED BY GOOGLE.
